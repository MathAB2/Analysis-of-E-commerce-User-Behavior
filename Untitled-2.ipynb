# %%
import numpy as  np   # type: ignore
import pandas as pd # type: ignore
import matplotlib.pyplot as plt # type: ignore
from datetime import datetime

import pandas as pd

columns = ['user_id', 'order_dt', 'order_products', 'order_amount']
columns = ['user_id', 'order_dt', 'order_products', 'order_amount']
data = pd.read_csv('CDNOW_master.txt', delimiter='\t', names=columns)
data.head()
data.describe()
data.info()
data['order_dt'] = pd.to_datetime(data['order_dt'], format='%Y%m%d')
data['month'] = data['order_dt'].values.astype('datetime64[M]')
data.head()

import matplotlib.pyplot as plt

plt.figure(figsize=(20, 15))

# 每月产品购买数量
plt.subplot(221)
data.groupby('month')['order_products'].sum().plot()
plt.title('每月产品购买数量')

plt.figure(figsize=(12, 4))

plt.subplot(121)
data['order_amount'].plot(kind='hist', bins=50)
plt.xlabel('每个订单的消费金额')

plt.subplot(122)
data.groupby(by='user_id')['order_products'].sum().plot(kind='hist', bins=50)
plt.xlabel('每个用户购买数量')

plt.show()

# 每月产品消费金额
plt.subplot(222)
data.groupby('month')['order_amount'].sum().plot()
plt.title('每月产品消费金额')

# 每月产品消费次数
plt.subplot(223)
data.groupby('month')['user_id'].count().plot()
plt.title('每月产品消费次数')

# 每月产品消费人数
plt.subplot(224)
data.groupby('month')['user_id'].nunique().plot()
plt.title('每月产品消费人数')

plt.show()




columns = ['user_id', 'order_dt', 'order_products', 'order_amount']
data = pd.read_table('CDNOW_master.txt', header=None, names=columns)

user_grouped = data.groupby('user_id').sum()
print(user_grouped.describe())
print('用户数量：', len(user_grouped))

data.plot(kind='scatter', x='order_products', y='order_amount')
plt.xlabel('产品购买量')
plt.ylabel('消费金额')
plt.title('产品购买量和消费金额散点图')
plt.show()

user_cumsum = data.groupby(by='user_id')['order_amount'].sum().sort_values().reset_index()
user_cumsum

import numpy as np

a = [1, 2, 3, 4, 5, 6]
print(np.cumsum(a))

user_cumsum['amount_cumsum'] = np.cumsum(user_cumsum['order_amount'])
user_cumsum.tail()

amount_total = user_cumsum['amount_cumsum'].max()
user_cumsum['prop'] = user_cumsum.apply(lambda x: x['amount_cumsum'] / amount_total, axis=1)
user_cumsum.tail()


import pandas as pd
import matplotlib.pyplot as plt

# 用户贡献度分布图
user_cumsum['prop'].plot()
plt.title('用户贡献度分布图')

# 用户首次购买时间
data['order_date'] = pd.to_datetime(data['order_dt'], format='%Y%m%d')
data.groupby(by='user_id')['order_date'].min().value_counts().plot()
plt.ylabel('用户数量')

data.groupby(by='user_id')['order_date'].max().value_counts().plot()
plt.ylabel('用户数量')

data = pd.DataFrame({
    'a': [0, 1, 2, 3, 4, 5],
    'b': [5, 4, 3, 2, 1, 0]
})
data.shift(axis=0)
data.shift(axis=1)
import numpy as np
import matplotlib.pyplot as plt

# Assuming order_diff is a list or array of timedelta values
# We'll simulate some data for this example
order_diff = np.random.rand(100) * np.timedelta64(1, 'D')

# Plot the

user_life = pd.DataFrame({
    'max': pd.to_datetime(['2023-01-01', '2023-01-03', '2023-01-05', '2023-01-07', '2023-01-09']),
    'min': pd.to_datetime(['2023-01-01', '2023-01-01', '2023-01-04', '2023-01-07', '2023-01-09']),
})

# 计算用户生命周期中仅消费一次和多次消费的情况
user_life['unique'] = (user_life['max'] == user_life['min']).map({True: '仅  费一次', False: '多次消费'})

# 绘制饼图
user_life['unique'].value_counts().plot.pie(autopct='%1.1f%%')
plt.legend(['仅消费一次', '多次消费'])
plt.show()

user_life = pd.DataFrame({
    'max': pd.to_datetime(['2023-01-01', '2023-01-03', '2023-01-05', '2023-01-07', '2023-01-09']),
    'min': pd.to_datetime(['2023-01-01', '2023-01-01', '2023-01-04', '2023-01-07', '2023-01-09']),
})
# 计算用户生命周期的时间跨度描述性统计
lifecycle_stats = (user_life['max'] - user_life['min']).describe()
print(lifecycle_stats)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# 所有用户生命周期直方图
plt.subplot(121)
(user_life['max'] - user_life['min']).dt.days.hist(bins=15)
plt.title('所有用户生命周期直方图')
plt.xlabel('生命周期天数')
plt.ylabel('用户人数')

# 多次消费的用户生命周期直方图
plt.subplot(122)
u_1 = ((user_life['max'] - user_life['min']).reset_index()[0] / np.timedelta64(1, 'D'))
u_1[u_1 > 0].hist(bins=15)
plt.title('多次消费的用户生命周期直方图')
plt.xlabel('生命周期天数')
plt.ylabel('用户人数')
plt.show()

print(data.columns)
print(data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69659 entries, 0 to 69658
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user_id         69659 non-null  object
#  1   order_dt        0 non-null      float64
#  2   order_products  0 non-null      float64
#  3   order_amount    0 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 2.1+ MB
# C:\Users\赵天赐\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 27599 (\N{CJK UNIFIED IDEOGRAPH-6BCF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\赵天赐\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26376 (\N{CJK UNIFIED IDEOGRAPH-6708}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
